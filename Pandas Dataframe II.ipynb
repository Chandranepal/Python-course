# %% [markdown]
# ### Remainning of dataframe I

# %% [markdown]
# ### .sort_values method() in pandas

# %%
import pandas as pd
df=pd.read_csv("nba.csv").dropna(how="all")

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
df.sort_values(by="Name",ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# ..               ...                     ...     ...      ...   ...    ...
# 312       Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
#
#      Weight         College      Salary
# ...

# %%
df.sort_values("Age") #inplace=True can be done
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 226       Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 122        Devin Booker            Phoenix Suns     1.0       SG  19.0    6-6
# 40   Kristaps Porzingis         New York Knicks     6.0       PF  20.0    7-3
# 401          Tyus Jones  Minnesota Timberwolves     1.0       PG  20.0    6-2
# 427     Cliff Alexander  Portland Trail Blazers    34.0       PF  20.0    6-8
# ..                  ...                     ...     ...      ...   ...    ...
# 261        Vince Carter       Memphis Grizzlies    15.0       SG  39.0    6-6
# 102      Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
# 298          Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
# 400       Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 304        Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
#
# ...

# %% [markdown]
# ### .sort_index method

# %%
df.sort_index(ascending=False)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#                College     Salary
# 456             Kansas   947276.0
# ...

# %%
df.sort_values(["Number","Salary","Name"],inplace=True)

# %%
df
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 291   Orlando Johnson    New Orleans Pelicans     0.0       SG  27.0    6-5
# 248  Andrew Goudelock         Houston Rockets     0.0       PG  27.0    6-3
# 347   Josh Richardson              Miami Heat     0.0       SG  22.0    6-6
# 266    JaMychal Green       Memphis Grizzlies     0.0       PF  25.0    6-9
# 47      Isaiah Canaan      Philadelphia 76ers     0.0       PG  25.0    6-0
# ..                ...                     ...     ...      ...   ...    ...
# 398   Nemanja Bjelica  Minnesota Timberwolves    88.0       PF  28.0   6-10
# 372       Drew Gooden      Washington Wizards    90.0       PF  34.0   6-10
# 5        Amir Johnson          Boston Celtics    90.0       PF  29.0    6-9
# 68     Lucas Nogueira         Toronto Raptors    92.0        C  23.0    7-0
# 1         Jae Crowder          Boston Celtics    99.0       SF  25.0    6-6
#
#      Weight           College      Salary
# ...

# %% [markdown]
# ### Rank values with .rank() method

# %%
df=pd.read_csv("nba.csv").dropna(how="all")
df.Salary=df.Salary.fillna(0).astype("int")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College   Salary
# 0                Texas  7730337
# ...

# %%
df["Salary Rank"]=df["Salary"].rank(ascending=False).astype("int")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College   Salary  Salary Rank
# 0                Texas  7730337           97
# ...

# %% [markdown]
# # Day II: Dataframe II

# %%
df=pd.read_csv("employees.csv")

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# Looking into the dataframe, we came to know that two columns are in date and time format and Senior Management is in boolean category and Gender is also category.

# %%
df=pd.read_csv("employees.csv",parse_dates=["Start Date","Last Login Time"])

# %%
df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-06-02 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-06-02 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-06-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-06-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-06-02 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-06-02 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-06-02 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-06-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-06-02 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-06-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# ### Filtering a dataframe based on one condition or more than one

# %%
req=df["Gender"]=="Male"
df[req]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-06-02 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2020-06-02 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2020-06-02 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2020-06-02 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2020-06-02 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2020-06-02 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2020-06-02 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2020-06-02 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2020-06-02 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2020-06-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
#this can be also one as:
df[df["Gender"]=="Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-06-02 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2020-06-02 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2020-06-02 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2020-06-02 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2020-06-02 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2020-06-02 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2020-06-02 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2020-06-02 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2020-06-02 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2020-06-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
req1=df["Gender"]=="Male" #1
req2=df["Team"]=="Marketing" #1
df[req1 & req2]              #1 & 1 = 1
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-06-02 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2020-06-02 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2020-06-02 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2020-06-02 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2020-06-02 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2020-06-02 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2020-06-02 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2020-06-02 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2020-06-02 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2020-06-02 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2020-06-02 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2020-06-02 09:45:00   55281    4.935
# ...

# %%
df[(df["Gender"]=="Male") & (df["Team"]=="Marketing")]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-06-02 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2020-06-02 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2020-06-02 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2020-06-02 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2020-06-02 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2020-06-02 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2020-06-02 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2020-06-02 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2020-06-02 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2020-06-02 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2020-06-02 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2020-06-02 09:45:00   55281    4.935
# ...

# %%
req1=df["Gender"]=="Male" 
req2=df["Team"]=="Marketing" 
req3=df["Start Date"]>"2011-06-01"
df[req1 & req2 & req3]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2020-06-02 10:20:00   61602   11.849
# 216    Matthew   Male 2013-07-31 2020-06-02 08:04:00  142373    2.462
# 452      Scott   Male 2012-11-17 2020-06-02 14:47:00  146812    1.965
# 496     Johnny   Male 2016-02-26 2020-06-02 19:39:00   76394    5.437
# 503      Roger   Male 2015-08-03 2020-06-02 16:56:00  125033    4.887
# 556     Arthur   Male 2014-12-16 2020-06-02 16:56:00   66819    6.639
# 696     Samuel   Male 2012-05-25 2020-06-02 16:40:00   85550   11.593
# 867       Earl   Male 2013-06-15 2020-06-02 03:00:00   48046    7.737
# 947        NaN   Male 2012-07-30 2020-06-02 15:07:00  107351    5.329
# 994     George   Male 2013-06-21 2020-06-02 17:47:00   98874    4.479
#
#      Senior Management       Team
# 101               True  Marketing
# 216              False  Marketing
# 452               True  Marketing
# 496               True  Marketing
# ...

# %%
req1=df["Gender"]=="Male" 
req2=df["Team"]=="Marketing" 
req3=df["Start Date"]>"2011-06-01"
df[(req1 & req2) | req3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-06-02 12:42:00   97308    6.945
# 7          NaN  Female 2015-07-20 2020-06-02 10:43:00   45906   11.598
# 15     Lillian  Female 2016-06-05 2020-06-02 06:09:00   59414    1.256
# 21     Matthew    Male 1995-09-05 2020-06-02 02:12:00  100612   13.645
# 22      Joshua     NaN 2012-03-08 2020-06-02 01:58:00   90816   18.816
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-06-02 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2020-06-02 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2020-06-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-06-02 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-06-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
req1=df["Senior Management"]==True
req2=df["Start Date"]<"1990-01-01"
df[req1 & req2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 6         Ruby  Female 1987-08-17 2020-06-02 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2020-06-02 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2020-06-02 01:08:00  112807   17.492
# 28       Terry    Male 1981-11-27 2020-06-02 18:30:00  124008   13.464
# 37       Linda  Female 1981-10-19 2020-06-02 20:49:00   57427    9.557
# ..         ...     ...        ...                 ...     ...      ...
# 960    Stephen    Male 1989-10-29 2020-06-02 23:34:00   93997   18.093
# 964      Bruce    Male 1980-05-07 2020-06-02 20:00:00   35802   12.391
# 970      Alice  Female 1988-09-03 2020-06-02 20:54:00   63571   15.397
# 982       Rose  Female 1982-04-06 2020-06-02 10:43:00   91411    8.639
# 990      Robin  Female 1987-07-24 2020-06-02 13:35:00  100765   10.982
#
#      Senior Management                  Team
# 6                 True               Product
# ...

# %% [markdown]
# ### .isnull() and .notnull() methods

# %%
condition=df["Gender"].notnull()
df[condition]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-06-02 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-06-02 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-06-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-06-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-06-02 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-06-02 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-06-02 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-06-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-06-02 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-06-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# ### The .between() method

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-06-02 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-06-02 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-06-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-06-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-06-02 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-06-02 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-06-02 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-06-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-06-02 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-06-02 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
req1=df["Salary"].between(61933,67656) #inclusive of the end points
df[req1]
# Out:
#      First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1        Thomas    Male 1996-03-31 2020-06-02 06:53:00   61933    4.170
# 6          Ruby  Female 1987-08-17 2020-06-02 16:20:00   65476   10.012
# 10       Louise  Female 1980-08-12 2020-06-02 09:01:00   63241   15.132
# 20         Lois     NaN 1995-04-22 2020-06-02 19:18:00   64714    4.934
# 41    Christine     NaN 2015-06-28 2020-06-02 01:08:00   66582   11.308
# 47        Kathy  Female 2005-06-22 2020-06-02 04:51:00   66820    9.000
# 57        Henry    Male 1996-06-26 2020-06-02 01:44:00   64715   15.107
# 59        Irene  Female 1997-05-07 2020-06-02 09:32:00   66851   11.279
# 74       Thomas    Male 1995-06-04 2020-06-02 14:24:00   62096   17.029
# 88        Donna  Female 1991-11-27 2020-06-02 13:59:00   64088    6.155
# 112      Willie    Male 2003-11-27 2020-06-02 06:21:00   64363    4.023
# 127     William    Male 2002-09-29 2020-06-02 16:09:00   66521    5.830
# ...

# %%
df[df["Bonus %"].between(2,5)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2020-06-02 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2020-06-02 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2020-06-02 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2020-06-02 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2020-06-02 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2020-06-02 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2020-06-02 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2020-06-02 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2020-06-02 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2020-06-02 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# ...

# %%
df[df["Last Login Time"].between("06:45AM","05:45PM")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-06-02 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-06-02 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-06-02 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-06-02 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-06-02 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2020-06-02 13:35:00  100765   10.982
# 992    Anthony    Male 2011-10-16 2020-06-02 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2020-06-02 15:53:00   56450   19.040
# 997    Russell    Male 2013-05-20 2020-06-02 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-06-02 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [raw]
# Homework:
# Read the file with name 'boulder.csv'. Do the folloing.
# a. Find the dates for which max_temp was greater than 90.
# b. Find the dates for which max_temp was in the range [80-90].
# c. Find the dates for which precipitation was less than -1.
