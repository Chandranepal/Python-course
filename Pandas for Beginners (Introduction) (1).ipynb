# %% [raw]
# Phase I:
# a. Reading Downloaded data (mostly csv)
# b. Basic Initialization

# %%
import pandas as pd
df=pd.read_csv("nba.csv")

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
df.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
df.shape
# Out:
# (458, 9)

# %% [markdown]
# df.shape = rows*columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# ### Selecting one or two or more than two desired columns

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
df["Name"]
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
#This can be also done as:
df.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %% [markdown]
# But the later one has a defect. If the column name is splitted (like Full Name), this method doesnot work.

# %%
#two columns selection
df[["Name","Team"]]
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
#more than two columns
df[["Name","Team","Salary"]]
# Out:
#               Name            Team     Salary
# 0    Avery Bradley  Boston Celtics  7730337.0
# 1      Jae Crowder  Boston Celtics  6796117.0
# 2     John Holland  Boston Celtics        NaN
# 3      R.J. Hunter  Boston Celtics  1148640.0
# 4    Jonas Jerebko  Boston Celtics  5000000.0
# ..             ...             ...        ...
# 453   Shelvin Mack       Utah Jazz  2433333.0
# 454      Raul Neto       Utah Jazz   900000.0
# 455   Tibor Pleiss       Utah Jazz  2900000.0
# 456    Jeff Withey       Utah Jazz   947276.0
# 457            NaN             NaN        NaN
#
# [458 rows x 3 columns]

# %%
#this can be also done as:
req=["Name","Team","Age","Salary"]
df[req]
# Out:
#               Name            Team   Age     Salary
# 0    Avery Bradley  Boston Celtics  25.0  7730337.0
# 1      Jae Crowder  Boston Celtics  25.0  6796117.0
# 2     John Holland  Boston Celtics  27.0        NaN
# 3      R.J. Hunter  Boston Celtics  22.0  1148640.0
# 4    Jonas Jerebko  Boston Celtics  29.0  5000000.0
# ..             ...             ...   ...        ...
# 453   Shelvin Mack       Utah Jazz  26.0  2433333.0
# 454      Raul Neto       Utah Jazz  24.0   900000.0
# 455   Tibor Pleiss       Utah Jazz  26.0  2900000.0
# 456    Jeff Withey       Utah Jazz  26.0   947276.0
# 457            NaN             NaN   NaN        NaN
#
# [458 rows x 4 columns]

# %% [markdown]
# If you wish to create a new dataframe by selecting the desired columns then we must assign a variable.

# %%
dfnew=df[["Name","Team","Age","Salary"]]

# %%
dfnew
# Out:
#               Name            Team   Age     Salary
# 0    Avery Bradley  Boston Celtics  25.0  7730337.0
# 1      Jae Crowder  Boston Celtics  25.0  6796117.0
# 2     John Holland  Boston Celtics  27.0        NaN
# 3      R.J. Hunter  Boston Celtics  22.0  1148640.0
# 4    Jonas Jerebko  Boston Celtics  29.0  5000000.0
# ..             ...             ...   ...        ...
# 453   Shelvin Mack       Utah Jazz  26.0  2433333.0
# 454      Raul Neto       Utah Jazz  24.0   900000.0
# 455   Tibor Pleiss       Utah Jazz  26.0  2900000.0
# 456    Jeff Withey       Utah Jazz  26.0   947276.0
# 457            NaN             NaN   NaN        NaN
#
# [458 rows x 4 columns]

# %% [markdown]
# ### Adding new column into the dataframe

# %%
df=pd.read_csv("nba.csv")
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
df["Sport"]="Basketball"

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
df["League"]="Everest Premier League"

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport                  League
# 0              Texas  7730337.0  Basketball  Everest Premier League
# 1          Marquette  6796117.0  Basketball  Everest Premier League
# 2  Boston University        NaN  Basketball  Everest Premier League

# %%
df.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary       Sport                  League
# 455  2900000.0  Basketball  Everest Premier League
# 456   947276.0  Basketball  Everest Premier League
# 457        NaN  Basketball  Everest Premier League

# %% [markdown]
# ### Brodcasting Operation

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport                  League
# 0              Texas  7730337.0  Basketball  Everest Premier League
# 1          Marquette  6796117.0  Basketball  Everest Premier League
# 2  Boston University        NaN  Basketball  Everest Premier League

# %%
df.Age=df.Age+5
#or: df["Age"]=df["Age"]+5

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  30.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  30.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  32.0    6-5   205.0
#
#              College     Salary       Sport                  League
# 0              Texas  7730337.0  Basketball  Everest Premier League
# 1          Marquette  6796117.0  Basketball  Everest Premier League
# 2  Boston University        NaN  Basketball  Everest Premier League

# %%
df.Salary=df.Salary-50000

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  30.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  30.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  32.0    6-5   205.0
#
#              College     Salary       Sport                  League
# 0              Texas  7680337.0  Basketball  Everest Premier League
# 1          Marquette  6746117.0  Basketball  Everest Premier League
# 2  Boston University        NaN  Basketball  Everest Premier League

# %%
df["Weight in Kg"]=df["Weight"]*0.453592

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  30.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  30.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  32.0    6-5   205.0
#
#              College     Salary       Sport                  League  \
# 0              Texas  7680337.0  Basketball  Everest Premier League
# 1          Marquette  6746117.0  Basketball  Everest Premier League
# 2  Boston University        NaN  Basketball  Everest Premier League
#
#    Weight in Kg
# 0      81.64656
# 1     106.59412
# 2      92.98636

# %%
#reading the dataframe again

# %%
df=pd.read_csv("nba.csv")

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
df["Salary in Millions"]=df["Salary"]/1000000

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Salary in Millions
# 0              Texas  7730337.0            7.730337
# 1          Marquette  6796117.0            6.796117
# 2  Boston University        NaN                 NaN

# %% [markdown]
# ### Deleting the columns

# %%
df.drop("Salary in Millions",axis=1,inplace=True)
#or: df=df.drop("Salary in Millions",axis=1)

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %% [markdown]
# ### A review of .value_counts() method

# %%
df["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Milwaukee Bucks           16
# New York Knicks           16
# Philadelphia 76ers        15
# Washington Wizards        15
# Golden State Warriors     15
# Chicago Bulls             15
# Detroit Pistons           15
# Charlotte Hornets         15
# Cleveland Cavaliers       15
# Dallas Mavericks          15
# Denver Nuggets            15
# Portland Trail Blazers    15
# Miami Heat                15
# Phoenix Suns              15
# Indiana Pacers            15
# Boston Celtics            15
# Oklahoma City Thunder     15
# Sacramento Kings          15
# San Antonio Spurs         15
# Houston Rockets           15
# Los Angeles Clippers      15
# Toronto Raptors           15
# Los Angeles Lakers        15
# Atlanta Hawks             15
# Utah Jazz                 15
# Brooklyn Nets             15
# Minnesota Timberwolves    14
# Orlando Magic             14
# Name: Team, dtype: int64

# %%
df["Age"].value_counts()
# Out:
# 24.0    47
# 25.0    45
# 27.0    41
# 23.0    41
# 26.0    36
# 28.0    31
# 30.0    31
# 29.0    28
# 22.0    26
# 31.0    22
# 21.0    19
# 20.0    19
# 33.0    14
# 32.0    13
# 36.0    10
# 34.0    10
# 35.0     9
# 38.0     4
# 37.0     4
# 40.0     3
# 39.0     2
# 19.0     2
# Name: Age, dtype: int64

# %% [markdown]
# ### Dropping the rows with nan values

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
df.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.dropna(how="all",inplace=True)

# %%
df.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %% [markdown]
# ### Deleting nan values from columns

# %%
df.dropna(subset=["College","Salary"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 9 columns):
# Name        364 non-null object
# Team        364 non-null object
# Number      364 non-null float64
# Position    364 non-null object
# Age         364 non-null float64
# Height      364 non-null object
# Weight      364 non-null float64
# College     364 non-null object
# Salary      364 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 28.4+ KB

# %% [markdown]
# ### Filling nan values in a dataframe

# %%
df=pd.read_csv("nba.csv")

# %%
df=df.dropna(how="all")

# %%
df.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
df.Salary.fillna(0,inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.College.fillna("College Dropout",inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
df.Age=df.Age.astype("int")

# %%
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C   26    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null int32
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null float64
# dtypes: float64(3), int32(1), object(5)
# memory usage: 33.9+ KB

# %%
df["Position"]=df["Position"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null category
# Age         457 non-null int32
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null float64
# dtypes: category(1), float64(3), int32(1), object(4)
# memory usage: 31.0+ KB
